# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
car_data=pd.read_csv("car_data .csv")

# %%
car_data.head(10)
# Out:
#         Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0           ritz  2014           3.35           5.59       27000    Petrol
# 1            sx4  2013           4.75           9.54       43000    Diesel
# 2           ciaz  2017           7.25           9.85        6900    Petrol
# 3        wagon r  2011           2.85           4.15        5200    Petrol
# 4          swift  2014           4.60           6.87       42450    Diesel
# 5  vitara brezza  2018           9.25           9.83        2071    Diesel
# 6           ciaz  2015           6.75           8.12       18796    Petrol
# 7        s cross  2015           6.50           8.61       33429    Diesel
# 8           ciaz  2016           8.75           8.89       20273    Diesel
# 9           ciaz  2015           7.45           8.92       42367    Diesel
#
#   Seller_Type Transmission  Owner
# 0      Dealer       Manual      0
# 1      Dealer       Manual      0
# 2      Dealer       Manual      0
# ...

# %%
car_data.tail(10)
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 291     brio  2015           5.40           6.10       31427    Petrol
# 292     jazz  2016           6.40           8.40       12000    Petrol
# 293     city  2010           3.25           9.90       38000    Petrol
# 294    amaze  2014           3.75           6.80       33019    Petrol
# 295     city  2015           8.55          13.09       60076    Diesel
# 296     city  2016           9.50          11.60       33988    Diesel
# 297     brio  2015           4.00           5.90       60000    Petrol
# 298     city  2009           3.35          11.00       87934    Petrol
# 299     city  2017          11.50          12.50        9000    Diesel
# 300     brio  2016           5.30           5.90        5464    Petrol
#
#     Seller_Type Transmission  Owner
# 291      Dealer       Manual      0
# 292      Dealer       Manual      0
# 293      Dealer       Manual      0
# 294      Dealer       Manual      0
# ...

# %%
car_data.tail(10)
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 291     brio  2015           5.40           6.10       31427    Petrol
# 292     jazz  2016           6.40           8.40       12000    Petrol
# 293     city  2010           3.25           9.90       38000    Petrol
# 294    amaze  2014           3.75           6.80       33019    Petrol
# 295     city  2015           8.55          13.09       60076    Diesel
# 296     city  2016           9.50          11.60       33988    Diesel
# 297     brio  2015           4.00           5.90       60000    Petrol
# 298     city  2009           3.35          11.00       87934    Petrol
# 299     city  2017          11.50          12.50        9000    Diesel
# 300     brio  2016           5.30           5.90        5464    Petrol
#
#     Seller_Type Transmission  Owner
# 291      Dealer       Manual      0
# 292      Dealer       Manual      0
# 293      Dealer       Manual      0
# 294      Dealer       Manual      0
# ...

# %%
car_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 301 entries, 0 to 300
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Car_Name       301 non-null    object
#  1   Year           301 non-null    int64
#  2   Selling_Price  301 non-null    float64
#  3   Present_Price  301 non-null    float64
#  4   Kms_Driven     301 non-null    int64
#  5   Fuel_Type      301 non-null    object
#  6   Seller_Type    301 non-null    object
#  7   Transmission   301 non-null    object
#  8   Owner          301 non-null    int64
# dtypes: float64(2), int64(3), object(4)
# memory usage: 21.3+ KB

# %%
car_data.isnull().sum()
# Out:
# Car_Name         0
# Year             0
# Selling_Price    0
# Present_Price    0
# Kms_Driven       0
# Fuel_Type        0
# Seller_Type      0
# Transmission     0
# Owner            0
# dtype: int64

# %%
car_data.replace({'Fuel_Type':{'Petrol':0,'Diesel':1,'CNG':2}},inplace=True)
car_data.replace({'Seller_Type':{'Dealer':0,'Individual':1}},inplace=True)
car_data.replace({'Transmission':{'Manual':0,'Automatic':1}},inplace=True)

# %%
car_data.tail(30)
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven  Fuel_Type  \
# 271     city  2009           3.00          10.00       69562          0
# 272     city  2015           7.50          10.00       27600          0
# 273     jazz  2010           2.25           7.50       61203          0
# 274     brio  2014           5.30           6.80       16500          0
# 275     city  2016          10.90          13.60       30753          0
# 276     city  2015           8.65          13.60       24800          0
# 277     city  2015           9.70          13.60       21780          0
# 278     jazz  2016           6.00           8.40        4000          0
# 279     city  2014           6.25          13.60       40126          0
# 280     brio  2015           5.25           5.90       14465          0
# 281     city  2006           2.10           7.60       50456          0
# 282     city  2014           8.25          14.00       63000          1
# ...

# %%
print(car_data.Fuel_Type.value_counts())
# Out:
# 0    239
# 1     60
# 2      2
# Name: Fuel_Type, dtype: int64

# %%
print(car_data.Seller_Type.value_counts())
# Out:
# 0    195
# 1    106
# Name: Seller_Type, dtype: int64

# %%
X=car_data.drop(['Car_Name','Selling_Price'],axis=1)
Y=car_data['Selling_Price']

# %%
print(X)
print(Y)
# Out:
#      Year  Present_Price  Kms_Driven  Fuel_Type  Seller_Type  Transmission  \
# 0    2014           5.59       27000          0            0             0
# 1    2013           9.54       43000          1            0             0
# 2    2017           9.85        6900          0            0             0
# 3    2011           4.15        5200          0            0             0
# 4    2014           6.87       42450          1            0             0
# ..    ...            ...         ...        ...          ...           ...
# 296  2016          11.60       33988          1            0             0
# 297  2015           5.90       60000          0            0             0
# 298  2009          11.00       87934          0            0             0
# 299  2017          12.50        9000          1            0             0
# 300  2016           5.90        5464          0            0             0
#
#      Owner
# 0        0
# 1        0
# 2        0
# 3        0
# ...

# %%
final_data=pd.DataFrame({'Models':})

# %%
car_data.Car_Name.value_counts()
# Out:
# city                        26
# corolla altis               16
# verna                       14
# fortuner                    11
# brio                        10
#                             ..
# Honda CB Trigger             1
# Yamaha FZ S                  1
# Bajaj Pulsar 135 LS          1
# Activa 4g                    1
# Bajaj Avenger Street 220     1
# Name: Car_Name, Length: 98, dtype: int64

# %%
sns.barplot(x='Car_Name',y='Selling_Price',data=car_data)
# Out:
# <AxesSubplot:xlabel='Car_Name', ylabel='Selling_Price'>

# %%
sns.barplot(x='Fuel_Type',y='Selling_Price',data=car_data)
# Out:
# <AxesSubplot:xlabel='Fuel_Type', ylabel='Selling_Price'>

# %%
sns.barplot(x='Transmission',y='Selling_Price',data=car_data)
# Out:
# <AxesSubplot:xlabel='Transmission', ylabel='Selling_Price'>

# %%
sns.barplot(x='Seller_Type',y='Selling_Price',data=car_data)
# Out:
# <AxesSubplot:xlabel='Seller_Type', ylabel='Selling_Price'>

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(X,Y,test_size=0.2,random_state=42)

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import GradientBoostingRegressor

# %%
rf=RandomForestRegressor()
gb=GradientBoostingRegressor()

# %%
gb.fit(x_train,y_train)
# Out:
# GradientBoostingRegressor()

# %%
rf.fit(x_train,y_train)
# Out:
# RandomForestRegressor()

# %%
pred1=rf.predict(x_test)

# %%
pred2=gb.predict(x_test)

# %%
from sklearn import metrics

# %%
print(metrics.r2_score(pred1,y_test))
print(metrics.r2_score(pred2,y_test))
# Out:
# 0.9579267201800636
# 0.9706540183802631

# %%
input_data=[]
num=int(input())
input_data_array=np.asarray(input_data)
input_data_reshape=input_data_array.reshape(1,-1)
if(num==1)
    print(rf.predict(input_data_reshape))
else
    print(gb.predict(input_data_reshape))
