# %%
import numpy as np
import pandas as pd

# %%
data=pd.read_csv("gld_price_data.csv")

# %%
data.head(10)
# Out:
#         Date          SPX        GLD        USO        SLV   EUR/USD
# 0   1/2/2008  1447.160034  84.860001  78.470001  15.180000  1.471692
# 1   1/3/2008  1447.160034  85.570000  78.370003  15.285000  1.474491
# 2   1/4/2008  1411.630005  85.129997  77.309998  15.167000  1.475492
# 3   1/7/2008  1416.180054  84.769997  75.500000  15.053000  1.468299
# 4   1/8/2008  1390.189941  86.779999  76.059998  15.590000  1.557099
# 5   1/9/2008  1409.130005  86.550003  75.250000  15.520000  1.466405
# 6  1/10/2008  1420.329956  88.250000  74.019997  16.061001  1.480100
# 7  1/11/2008  1401.020020  88.580002  73.089996  16.077000  1.479006
# 8  1/14/2008  1416.250000  89.540001  74.250000  16.280001  1.486900
# 9  1/15/2008  1380.949951  87.989998  72.779999  15.834000  1.480210

# %%
data.tail()
# Out:
#            Date          SPX         GLD      USO      SLV   EUR/USD
# 2285   5/8/2018  2671.919922  124.589996  14.0600  15.5100  1.186789
# 2286   5/9/2018  2697.790039  124.330002  14.3700  15.5300  1.184722
# 2287  5/10/2018  2723.070068  125.180000  14.4100  15.7400  1.191753
# 2288  5/14/2018  2730.129883  124.489998  14.3800  15.5600  1.193118
# 2289  5/16/2018  2725.780029  122.543800  14.4058  15.4542  1.182033

# %%
data['Date'].value_counts()
# Out:
# 1/2/2008      1
# 12/15/2014    1
# 12/5/2014     1
# 12/8/2014     1
# 12/9/2014     1
#              ..
# 6/14/2011     1
# 6/13/2011     1
# 6/9/2011      1
# 6/8/2011      1
# 5/16/2018     1
# Name: Date, Length: 2290, dtype: int64

# %%
data=data.drop("Date",axis=1)

# %%
data.head(10)
# Out:
#            SPX        GLD        USO        SLV   EUR/USD
# 0  1447.160034  84.860001  78.470001  15.180000  1.471692
# 1  1447.160034  85.570000  78.370003  15.285000  1.474491
# 2  1411.630005  85.129997  77.309998  15.167000  1.475492
# 3  1416.180054  84.769997  75.500000  15.053000  1.468299
# 4  1390.189941  86.779999  76.059998  15.590000  1.557099
# 5  1409.130005  86.550003  75.250000  15.520000  1.466405
# 6  1420.329956  88.250000  74.019997  16.061001  1.480100
# 7  1401.020020  88.580002  73.089996  16.077000  1.479006
# 8  1416.250000  89.540001  74.250000  16.280001  1.486900
# 9  1380.949951  87.989998  72.779999  15.834000  1.480210

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(data['SPX'],data['GLD'])
plt.xlabel("spx")
plt.ylabel("GLD")
plt.title("SPX VS GLD")
plt.show()

# %%
plt.scatter(data['USO'],data['GLD'])
plt.title("OIL VS GOLD")
plt.xlabel("OIL")
plt.ylabel("GOLD")
plt.show()

# %%
plt.scatter(data['SLV'],data['GLD'])
plt.xlabel("SILVER")
plt.ylabel("GOLD")
plt.title("SILVER VS GOLD")
plt.show()

# %%
plt.scatter(data['EUR/USD'],data['GLD'])
plt.xlabel("eur/usd")
plt.ylabel("gold")
plt.title("eur/usd vs gold")
plt.show()

# %%
X=data.drop("GLD",axis=1)
Y=data["GLD"]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(X,Y,test_size=0.2,random_state=42)

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
rf=RandomForestRegressor()

# %%
rf.fit(x_train,y_train)
# Out:
# RandomForestRegressor()

# %%
data_predict=rf.predict(x_test)

# %%
from sklearn import metrics

# %%
print("the accuracy is",metrics.r2_score(data_predict,y_test))
# Out:
# the accuracy is 0.9906042161616403

# %%
plt.plot(data_predict,y_test)
plt.xlabel("predicted data")
plt.ylabel("the actual data")
plt.title("ml vs actual")
plt.show()

# %%
input__data=()
indput_data=np.asarray(input__data)
input_data_reshape=input_data.reshape(1,-1)
print(rf.predict(input_data_reshape))
